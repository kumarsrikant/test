# %%
# !pip install -U scikit-learn

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
train=pd.read_csv('House_Price_Train.csv')

# %%
test=pd.read_csv('House_Price_Test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(train['SalePrice'])
# Out:
# C:\Users\SK074909\Anaconda3\envs\Rython\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
sns.boxplot(train['SalePrice'])
# Out:
# C:\Users\SK074909\Anaconda3\envs\Rython\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='SalePrice'>

# %% [markdown]
# ### Supervised Machine Learning => Features and Target
# #### => Independent Variables and Dependent Var
# ### Features are 80

# %%
### Correlation tells you the association between numerical variables
### Eg. If temp rises electricity consumption will also increase

# %%
train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
corrmat=train.corr()
sns.heatmap(corrmat,vmax=8,square=True)
plt.show()

# %%
k=10
cols=corrmat.nlargest(k,'SalePrice')['SalePrice'].index

# %%
cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
corrmat.nlargest(k,'SalePrice')['SalePrice']
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64

# %%
cm=np.corrcoef(train[cols].values.T)
plt.figure(figsize=(10,10),dpi=80)
sns.heatmap(cm,cbar=True,annot=True,fmt='.2f',annot_kws={'size':8},yticklabels=cols.to_list(),xticklabels=cols.to_list())
plt.show()

# %% [markdown]
# ### Observations
# * All 9 variables are important
# * But some of them are correlated
# * grlivarea and totrmsabvgrd are correlated
# * garagecars and garagearea are correlated
# * totalbsmtsf and 1stflrsf are correlated

# %%
cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
train.drop(['TotalBsmtSF','GarageCars','TotalBsmtSF'],axis=1,inplace=True)
test.drop(['TotalBsmtSF','GarageCars','TotalBsmtSF'],axis=1,inplace=True)

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
### Missing Data
total=train.isnull().sum().sort_values(ascending=False)
percent=(train.isnull().sum()/train.isnull().count()).sort_values(ascending=False)
missing_data=pd.concat([total,percent],axis=1,keys=['Total','Percent'])

# %%
total
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# FireplaceQu     690
#                ...
# Heating           0
# MSSubClass        0
# CentralAir        0
# 1stFlrSF          0
# SalePrice         0
# Length: 79, dtype: int64

# %%
missing_data
# Out:
#              Total   Percent
# PoolQC        1453  0.995205
# MiscFeature   1406  0.963014
# Alley         1369  0.937671
# Fence         1179  0.807534
# FireplaceQu    690  0.472603
# ...            ...       ...
# Heating          0  0.000000
# MSSubClass       0  0.000000
# CentralAir       0  0.000000
# 1stFlrSF         0  0.000000
# SalePrice        0  0.000000
#
# [79 rows x 2 columns]

# %%
### Missing Data
total=test.isnull().sum().sort_values(ascending=False)
percent=(test.isnull().sum()/test.isnull().count()).sort_values(ascending=False)
missing_data=pd.concat([total,percent],axis=1,keys=['Total','Percent'])

# %%
missing_data
# Out:
#                Total   Percent
# PoolQC          1456  0.997944
# MiscFeature     1408  0.965045
# Alley           1352  0.926662
# Fence           1169  0.801234
# FireplaceQu      730  0.500343
# ...              ...       ...
# CentralAir         0  0.000000
# Electrical         0  0.000000
# 1stFlrSF           0  0.000000
# 2ndFlrSF           0  0.000000
# SaleCondition      0  0.000000
#
# [78 rows x 2 columns]

# %%
train.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'],axis=1,inplace=True)
test.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'],axis=1,inplace=True)

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
train.drop(['Id'],axis=1,inplace=True)
test.drop(['Id'],axis=1,inplace=True)

# %%
train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
train.fillna(train.mean(),inplace=True)
test.fillna(test.mean(),inplace=True)
# Out:
# C:\Users\SK074909\Anaconda3\envs\Rython\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# C:\Users\SK074909\Anaconda3\envs\Rython\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 73 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
set(train['MSZoning'])
# Out:
# {'C (all)', 'FV', 'RH', 'RL', 'RM'}

# %%
train.select_dtypes(include='object')
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# ...

# %%
train.select_dtypes(include='object').columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
cat_cols=['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
       'PavedDrive', 'SaleType', 'SaleCondition']

# %%
column_name=[]
count_of_uniques=[]
for i in cat_cols:
    column_name.append(i)
    count=len(set(train[i]))
    count_of_uniques.append(count)

# %%
cat_col_df=pd.DataFrame()
cat_col_df['columns']=column_name
cat_col_df['Count']=count_of_uniques

# %%
cat_col_df
# Out:
#           columns  Count
# 0        MSZoning      5
# 1          Street      2
# 2        LotShape      4
# 3     LandContour      4
# 4       Utilities      2
# 5       LotConfig      5
# 6       LandSlope      3
# 7    Neighborhood     25
# 8      Condition1      9
# 9      Condition2      8
# 10       BldgType      5
# 11     HouseStyle      8
# 12      RoofStyle      6
# 13       RoofMatl      8
# 14    Exterior1st     15
# 15    Exterior2nd     16
# 16     MasVnrType      5
# 17      ExterQual      4
# 18      ExterCond      5
# 19     Foundation      6
# 20       BsmtQual      5
# 21       BsmtCond      5
# 22   BsmtExposure      5
# 23   BsmtFinType1      7
# 24   BsmtFinType2      7
# 25        Heating      6
# 26      HeatingQC      5
# 27     CentralAir      2
# 28     Electrical      6
# 29    KitchenQual      4
# 30     Functional      7
# 31     GarageType      7
# 32   GarageFinish      4
# 33     GarageQual      6
# 34     GarageCond      6
# 35     PavedDrive      3
# ...

# %%
train.drop(['Neighborhood','Exterior1st','Exterior2nd','Condition1','Condition2','HouseStyle','RoofMatl','SaleType'],axis=1,inplace=True)
test.drop(['Neighborhood','Exterior1st','Exterior2nd','Condition1','Condition2','HouseStyle','RoofMatl','SaleType'],axis=1,inplace=True)

# %%
train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
final_cols=list(set(column_name).difference(set(['Neighborhood','Exterior1st','Exterior2nd','Condition1','Condition2','HouseStyle','RoofMatl','SaleType'])))

# %%
final_cols
# Out:
# ['Heating',
#  'Foundation',
#  'BsmtQual',
#  'MasVnrType',
#  'SaleCondition',
#  'HeatingQC',
#  'CentralAir',
#  'GarageType',
#  'GarageQual',
#  'PavedDrive',
#  'BsmtFinType1',
#  'MSZoning',
#  'BldgType',
#  'RoofStyle',
#  'LandContour',
#  'LotShape',
#  'BsmtFinType2',
#  'Electrical',
#  'Utilities',
#  'BsmtExposure',
#  'BsmtCond',
#  'LotConfig',
#  'Street',
#  'Functional',
#  'ExterCond',
#  'GarageCond',
#  'LandSlope',
#  'GarageFinish',
#  'KitchenQual',
#  'ExterQual']

# %%
test.dropna(axis=0,inplace=True)

# %%
test.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleCondition    0
# Length: 64, dtype: int64

# %%
from sklearn import preprocessing
for i in final_cols:
    le=preprocessing.LabelEncoder()
    le.fit(train[i])
    train[i]=le.transform(train[i])
    test[i]=le.transform(test[i])

# %%
train
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0     8450       1         3
# 1             20         3         80.0     9600       1         3
# 2             60         3         68.0    11250       1         0
# 3             70         3         60.0     9550       1         0
# 4             60         3         84.0    14260       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1455          60         3         62.0     7917       1         3
# 1456          20         3         85.0    13175       1         3
# 1457          70         3         66.0     9042       1         3
# 1458          20         3         68.0     9717       1         3
# 1459          20         3         75.0     9937       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  OpenPorchSF  \
# 0               3          0          4          0  ...           61
# ...

# %%
test
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             20         2         80.0    11622       1         3
# 1             20         3         81.0    14267       1         0
# 2             60         3         74.0    13830       1         0
# 3             60         3         78.0     9978       1         0
# 4            120         3         43.0     5005       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1451          20         3         80.0    13384       1         3
# 1452         160         4         21.0     1533       1         3
# 1455         160         4         21.0     1894       1         3
# 1456          20         3        160.0    20000       1         3
# 1458          60         3         74.0     9627       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  WoodDeckSF  \
# 0               3          0          4          0  ...         140
# ...

# %%
train.drop('YrSold',axis=1,inplace=True)
test.drop('YrSold',axis=1,inplace=True)

# %%
train
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0     8450       1         3
# 1             20         3         80.0     9600       1         3
# 2             60         3         68.0    11250       1         0
# 3             70         3         60.0     9550       1         0
# 4             60         3         84.0    14260       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1455          60         3         62.0     7917       1         3
# 1456          20         3         85.0    13175       1         3
# 1457          70         3         66.0     9042       1         3
# 1458          20         3         68.0     9717       1         3
# 1459          20         3         75.0     9937       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  WoodDeckSF  \
# 0               3          0          4          0  ...           0
# ...

# %%
test
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             20         2         80.0    11622       1         3
# 1             20         3         81.0    14267       1         0
# 2             60         3         74.0    13830       1         0
# 3             60         3         78.0     9978       1         0
# 4            120         3         43.0     5005       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1451          20         3         80.0    13384       1         3
# 1452         160         4         21.0     1533       1         3
# 1455         160         4         21.0     1894       1         3
# 1456          20         3        160.0    20000       1         3
# 1458          60         3         74.0     9627       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  PavedDrive  \
# 0               3          0          4          0  ...           2
# ...

# %%
num_cols=list(set(train.columns).difference(set(final_cols)))

# %%
num_cols
# Out:
# ['LotArea',
#  'BedroomAbvGr',
#  'LotFrontage',
#  'BsmtHalfBath',
#  'LowQualFinSF',
#  'YearBuilt',
#  '2ndFlrSF',
#  'GrLivArea',
#  'PoolArea',
#  'HalfBath',
#  'Fireplaces',
#  'FullBath',
#  'BsmtFinSF2',
#  '1stFlrSF',
#  'WoodDeckSF',
#  'ScreenPorch',
#  'OverallCond',
#  'MSSubClass',
#  'SalePrice',
#  'OpenPorchSF',
#  'GarageYrBlt',
#  'MiscVal',
#  'MasVnrArea',
#  'TotRmsAbvGrd',
#  'BsmtFinSF1',
#  'KitchenAbvGr',
#  'BsmtUnfSF',
#  'BsmtFullBath',
#  'GarageArea',
#  'EnclosedPorch',
#  'YearRemodAdd',
#  'MoSold',
#  'OverallQual',
#  '3SsnPorch']

# %%
cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
num_col=list(set(cols).difference(set(['TotalBsmtSF','GarageCars','TotalBsmtSF'])))

# %%
num_col
# Out:
# ['1stFlrSF',
#  'SalePrice',
#  'GarageArea',
#  'YearBuilt',
#  'TotRmsAbvGrd',
#  'GrLivArea',
#  'FullBath',
#  'OverallQual']

# %%
for i in ['1stFlrSF',
 'GarageArea',
 'YearBuilt',
 'TotRmsAbvGrd',
 'GrLivArea',
 'FullBath',
 'OverallQual']:
    scaler=StandardScaler()
    scaler.fit(train[[i]])
    train[i]=scaler.transform(train[[i]])
    test[i]=scaler.transform(test[[i]])

# %%
scaler=StandardScaler()
scaler.fit(train[['SalePrice']])
train['SalePrice']=scaler.transform(train[['SalePrice']])

# %%
train
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0     8450       1         3
# 1             20         3         80.0     9600       1         3
# 2             60         3         68.0    11250       1         0
# 3             70         3         60.0     9550       1         0
# 4             60         3         84.0    14260       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1455          60         3         62.0     7917       1         3
# 1456          20         3         85.0    13175       1         3
# 1457          70         3         66.0     9042       1         3
# 1458          20         3         68.0     9717       1         3
# 1459          20         3         75.0     9937       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  WoodDeckSF  \
# 0               3          0          4          0  ...           0
# ...

# %%
test
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             20         2         80.0    11622       1         3
# 1             20         3         81.0    14267       1         0
# 2             60         3         74.0    13830       1         0
# 3             60         3         78.0     9978       1         0
# 4            120         3         43.0     5005       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1451          20         3         80.0    13384       1         3
# 1452         160         4         21.0     1533       1         3
# 1455         160         4         21.0     1894       1         3
# 1456          20         3        160.0    20000       1         3
# 1458          60         3         74.0     9627       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  PavedDrive  \
# 0               3          0          4          0  ...           2
# ...

# %%
train_cols=final_cols+num_col
test_cols=final_cols+['1stFlrSF',
 'GarageArea',
 'YearBuilt',
 'TotRmsAbvGrd',
 'GrLivArea',
 'FullBath',
 'OverallQual']

# %%
train=train[train_cols]

# %%
test=test[test_cols]

# %%
test
# Out:
#       Heating  Foundation  BsmtQual  MasVnrType  SaleCondition  HeatingQC  \
# 0           1           1         3           2              4          4
# 1           1           1         3           1              4          4
# 2           1           2         2           2              4          2
# 3           1           2         3           1              4          0
# 4           1           2         2           2              4          0
# ...       ...         ...       ...         ...            ...        ...
# 1451        1           2         3           1              4          1
# 1452        1           1         3           2              0          4
# 1455        1           1         3           2              0          4
# 1456        1           1         3           2              0          0
# 1458        1           2         2           1              4          0
#
#       CentralAir  GarageType  GarageQual  PavedDrive  ...  GarageFinish  \
# ...

# %%
train
# Out:
#       Heating  Foundation  BsmtQual  MasVnrType  SaleCondition  HeatingQC  \
# 0           1           2         2           1              4          0
# 1           1           1         2           2              4          0
# 2           1           2         2           1              4          0
# 3           1           0         3           2              0          2
# 4           1           2         2           1              4          0
# ...       ...         ...       ...         ...            ...        ...
# 1455        1           2         2           2              4          0
# 1456        1           1         2           3              4          4
# 1457        1           4         3           2              4          0
# 1458        1           1         3           2              4          2
# 1459        1           1         3           2              4          2
#
#       CentralAir  GarageType  GarageQual  PavedDrive  ...  KitchenQual  \
# ...

# %%
y=train['SalePrice']
x=train.drop(['SalePrice'],axis=1)

# %%
x
# Out:
#       Heating  Foundation  BsmtQual  MasVnrType  SaleCondition  HeatingQC  \
# 0           1           2         2           1              4          0
# 1           1           1         2           2              4          0
# 2           1           2         2           1              4          0
# 3           1           0         3           2              0          2
# 4           1           2         2           1              4          0
# ...       ...         ...       ...         ...            ...        ...
# 1455        1           2         2           2              4          0
# 1456        1           1         2           3              4          4
# 1457        1           4         3           2              4          0
# 1458        1           1         3           2              4          2
# 1459        1           1         3           2              4          2
#
#       CentralAir  GarageType  GarageQual  PavedDrive  ...  GarageFinish  \
# ...

# %%
test
# Out:
#       Heating  Foundation  BsmtQual  MasVnrType  SaleCondition  HeatingQC  \
# 0           1           1         3           2              4          4
# 1           1           1         3           1              4          4
# 2           1           2         2           2              4          2
# 3           1           2         3           1              4          0
# 4           1           2         2           2              4          0
# ...       ...         ...       ...         ...            ...        ...
# 1451        1           2         3           1              4          1
# 1452        1           1         3           2              0          4
# 1455        1           1         3           2              0          4
# 1456        1           1         3           2              0          0
# 1458        1           2         2           1              4          0
#
#       CentralAir  GarageType  GarageQual  PavedDrive  ...  GarageFinish  \
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
X_train
# Out:
#       Heating  Foundation  BsmtQual  MasVnrType  SaleCondition  HeatingQC  \
# 245         1           1         2           1              4          2
# 1080        1           1         3           1              0          0
# 324         1           1         2           1              4          0
# 1111        1           1         3           1              4          4
# 1395        1           2         2           1              4          0
# ...       ...         ...       ...         ...            ...        ...
# 336         1           2         0           3              4          0
# 378         1           2         0           3              5          0
# 761         1           2         3           2              4          4
# 1252        1           1         3           2              4          4
# 365         1           1         3           2              4          2
#
#       CentralAir  GarageType  GarageQual  PavedDrive  ...  GarageFinish  \
# ...

# %%
X_test
# Out:
#       Heating  Foundation  BsmtQual  MasVnrType  SaleCondition  HeatingQC  \
# 831         1           2         2           2              4          0
# 1448        1           1         1           2              4          2
# 201         1           1         3           2              4          4
# 1011        1           1         4           2              4          4
# 385         1           2         2           1              4          0
# ...       ...         ...       ...         ...            ...        ...
# 34          1           2         0           1              4          0
# 862         1           2         2           2              4          4
# 94          1           2         2           2              4          0
# 651         1           1         3           2              4          4
# 885         1           2         0           1              0          0
#
#       CentralAir  GarageType  GarageQual  PavedDrive  ...  GarageFinish  \
# ...

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,pred)
# Out:
# 1.0

# %%
pred
# Out:
# array([-3.76768695e-01, -8.67857994e-01, -1.18632012e-01, -1.01896239e+00,
#         1.39504670e-01, -6.19678625e-02, -7.67121727e-01, -3.38992595e-01,
#        -6.41201394e-01,  2.48791888e+00,  2.69086468e+00, -1.62704129e-01,
#        -8.04897827e-01, -6.60089444e-01, -3.78027898e-01,  3.08604046e+00,
#        -1.20784289e+00, -1.11969866e+00,  1.51833232e+00, -1.28589327e-02,
#        -3.90619932e-01, -7.67121727e-01, -4.52320895e-01,  3.41280373e+00,
#        -5.02689028e-01, -3.45288612e-01,  1.20982750e+00, -5.65649195e-01,
#         8.13178452e-01, -6.53793428e-01, -7.79713761e-01,  1.09649920e+00,
#         4.85785586e-01,  1.70984754e-01, -3.15067732e-01,  7.31330235e-01,
#         1.14320604e-01, -5.53057161e-01, -6.72681478e-01,  1.64688737e-01,
#        -7.04161561e-01, -1.83870376e+00,  6.99850152e-01,  4.29121436e-01,
#        -2.69736412e-01, -4.14544795e-01,  1.19723547e+00, -9.97439624e-02,
# ...

# %%
y_test
# Out:
# 831    -0.376769
# 1448   -0.867858
# 201    -0.118632
# 1011   -1.018962
# 385     0.139505
#           ...
# 34      1.216124
# 862    -0.364177
# 94      0.300053
# 651    -0.918226
# 885     1.863354
# Name: SalePrice, Length: 365, dtype: float64

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm
from scipy import stats
x2=sm.add_constant(X_train)
est=sm.OLS(y_train,x2)
est2=est.fit()

# %%
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.124e+30
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):               0.00
# Time:                        21:04:57   Log-Likelihood:                 34820.
# No. Observations:                1095   AIC:                        -6.956e+04
# Df Residuals:                    1057   BIC:                        -6.937e+04
# Df Model:                          37
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
new_x_train=train[['Heating','MasVnrType','HeatingQC','GarageType','RoofStyle','LandContour','Electrical','BsmtExposure','LotConfig','Functional','OverallQual','SalePrice']]

# %%
new_test=test[['Heating','MasVnrType','HeatingQC','GarageType','RoofStyle','LandContour','Electrical','BsmtExposure','LotConfig','Functional','OverallQual']]

# %%
y=new_x_train['SalePrice']
x=new_x_train.drop(['SalePrice'],axis=1)

# %%
x
# Out:
#       Heating  MasVnrType  HeatingQC  GarageType  RoofStyle  LandContour  \
# 0           1           1          0           1          1            3
# 1           1           2          0           1          1            3
# 2           1           1          0           1          1            3
# 3           1           2          2           5          1            3
# 4           1           1          0           1          1            3
# ...       ...         ...        ...         ...        ...          ...
# 1455        1           2          0           1          1            3
# 1456        1           3          4           1          1            3
# 1457        1           2          0           1          1            3
# 1458        1           2          2           1          3            3
# 1459        1           2          2           1          1            3
#
#       Electrical  BsmtExposure  LotConfig  Functional  OverallQual
# ...

# %%
new_test
# Out:
#       Heating  MasVnrType  HeatingQC  GarageType  RoofStyle  LandContour  \
# 0           1           2          4           1          1            3
# 1           1           1          4           1          3            3
# 2           1           2          2           1          1            3
# 3           1           1          0           1          1            3
# 4           1           2          0           1          1            1
# ...       ...         ...        ...         ...        ...          ...
# 1451        1           1          1           1          1            3
# 1452        1           2          4           4          1            3
# 1455        1           2          4           4          1            3
# 1456        1           2          0           5          1            3
# 1458        1           1          0           1          1            3
#
#       Electrical  BsmtExposure  LotConfig  Functional  OverallQual
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
X_train
# Out:
#       Heating  MasVnrType  HeatingQC  GarageType  RoofStyle  LandContour  \
# 227         1           1          4           5          1            3
# 951         1           2          2           5          1            3
# 157         1           1          0           3          1            3
# 1040        1           0          0           1          1            3
# 917         1           2          0           1          1            3
# ...       ...         ...        ...         ...        ...          ...
# 407         1           2          0           1          1            3
# 148         1           1          0           6          1            3
# 505         1           1          2           5          3            3
# 358         1           1          0           3          3            3
# 848         1           2          4           5          1            0
#
#       Electrical  BsmtExposure  LotConfig  Functional  OverallQual
# ...

# %%
X_test
# Out:
#       Heating  MasVnrType  HeatingQC  GarageType  RoofStyle  LandContour  \
# 828         1           2          4           1          0            2
# 1147        1           2          0           1          1            0
# 905         1           3          4           1          1            3
# 1154        1           3          4           1          1            3
# 1424        1           2          4           5          3            3
# ...       ...         ...        ...         ...        ...          ...
# 63          1           2          2           5          1            0
# 132         1           2          2           5          1            3
# 136         1           1          4           1          1            3
# 1268        1           1          0           3          1            3
# 192         1           2          0           1          1            3
#
#       Electrical  BsmtExposure  LotConfig  Functional  OverallQual
# ...

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,pred)
# Out:
# 1.0

# %%
import statsmodels.api as sm
from scipy import stats
x2=sm.add_constant(X_train)
est=sm.OLS(y_train,x2)
est2=est.fit()

# %%
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.507e+31
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):               0.00
# Time:                        21:13:28   Log-Likelihood:                 35724.
# No. Observations:                1095   AIC:                        -7.142e+04
# Df Residuals:                    1083   BIC:                        -7.136e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
new_x_train=train[['MasVnrType','GarageType','RoofStyle','Electrical','BsmtExposure','LotConfig','OverallQual','SalePrice']]

# %%
new_test=test[['MasVnrType','GarageType','RoofStyle','Electrical','BsmtExposure','LotConfig','OverallQual']]

# %%
y=new_x_train['SalePrice']
x=new_x_train.drop(['SalePrice'],axis=1)

# %%
x
# Out:
#       MasVnrType  GarageType  RoofStyle  Electrical  BsmtExposure  LotConfig  \
# 0              1           1          1           4             3          4
# 1              2           1          1           4             1          2
# 2              1           1          1           4             2          4
# 3              2           5          1           4             3          0
# 4              1           1          1           4             0          2
# ...          ...         ...        ...         ...           ...        ...
# 1455           2           1          1           4             3          4
# 1456           3           1          1           4             3          4
# 1457           2           1          1           4             3          4
# 1458           2           1          3           0             2          4
# 1459           2           1          1           4             3          4
#
#       OverallQual
# 0        0.347273
# ...

# %%
new_test
# Out:
#       MasVnrType  GarageType  RoofStyle  Electrical  BsmtExposure  LotConfig  \
# 0              2           1          1           4             3          4
# 1              1           1          3           4             3          0
# 2              2           1          1           4             3          4
# 3              1           1          1           4             3          4
# 4              2           1          1           4             3          4
# ...          ...         ...        ...         ...           ...        ...
# 1451           1           1          1           4             0          4
# 1452           2           4          1           4             3          4
# 1455           2           4          1           4             3          4
# 1456           2           5          1           4             3          4
# 1458           1           1          1           4             0          4
#
#       OverallQual
# 0       -0.795151
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
X_train
# Out:
#       MasVnrType  GarageType  RoofStyle  Electrical  BsmtExposure  LotConfig  \
# 1236           3           3          1           4             3          4
# 1113           2           1          1           4             3          4
# 710            2           6          1           4             3          4
# 46             2           1          1           4             3          1
# 1225           1           1          3           4             0          4
# ...          ...         ...        ...         ...           ...        ...
# 964            1           3          1           4             3          0
# 1161           1           5          3           4             3          1
# 994            3           1          3           4             1          2
# 1185           2           1          1           4             3          4
# 1219           1           6          1           4             3          4
#
#       OverallQual
# 1236    -0.068264
# ...

# %%
X_test
# Out:
#       MasVnrType  GarageType  RoofStyle  Electrical  BsmtExposure  LotConfig  \
# 599            2           1          1           4             3          4
# 288            1           5          1           4             3          4
# 1455           2           1          1           4             3          4
# 1065           2           1          1           4             1          4
# 1333           2           5          1           4             3          0
# ...          ...         ...        ...         ...           ...        ...
# 1010           2           1          1           4             3          4
# 535            2           6          1           4             1          4
# 730            2           1          1           4             3          4
# 1290           1           1          3           4             0          0
# 349            1           1          3           4             3          4
#
#       OverallQual
# 599     -0.376769
# ...

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,pred)
# Out:
# 1.0

# %%
import statsmodels.api as sm
from scipy import stats
x2=sm.add_constant(X_train)
est=sm.OLS(y_train,x2)
est2=est.fit()

# %%
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.839e+32
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):               0.00
# Time:                        21:15:49   Log-Likelihood:                 36568.
# No. Observations:                1095   AIC:                        -7.312e+04
# Df Residuals:                    1087   BIC:                        -7.308e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
